# %%
#Import required Libraries
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('whitegrid')

# %%
#Extracting Csv Dataset from folder
df = pd.read_csv("Downloads/Heart Disease data.csv")
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# 1         0   0     3       0
# 2         0   0     3       0
# 3         2   1     3       0
# 4         1   3     2       0
# ...     ...  ..   ...     ...
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0
#
# [1025 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
 df.shape
# Out:
# (1025, 14)

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000

# %%
df.median()
# Out:
# age          56.0
# sex           1.0
# cp            1.0
# trestbps    130.0
# chol        240.0
# fbs           0.0
# restecg       1.0
# thalach     152.0
# exang         0.0
# oldpeak       0.8
# slope         1.0
# ca            0.0
# thal          2.0
# target        1.0
# dtype: float64

# %% [markdown]
# # Percentage of people having heart disease

# %%
(df['target']==1).mean()*100
# Out:
# 51.31707317073171

# %%
num = df.groupby('target').size()
num
# Out:
# target
# 0    499
# 1    526
# dtype: int64

# %%
def pavan_hr(r):
    if r == 0:
        return 'Absence'
    elif r ==1 :
        return 'Presence'

# %%
df['Heart_Disease'] = df['target'].apply(pavan_hr)
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target Heart_Disease
# 0   2     3       0       Absence
# 1   0     3       0       Absence
# 2   0     3       0       Absence
# 3   1     3       0       Absence
# 4   3     2       0       Absence

# %%
hd = df.groupby('Heart_Disease')['target'].count()
hd
# Out:
# Heart_Disease
# Absence     499
# Presence    526
# Name: target, dtype: int64

# %%
#Coverting numerical data into categorical data
def gen(r):
    if r == 1:
       return 'Male'
    elif r ==0:
       return 'female'

# %%
df['sex1'] = df['sex'].apply(gen)
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target Heart_Disease    sex1
# 0   2     3       0       Absence    Male
# 1   0     3       0       Absence    Male
# 2   0     3       0       Absence    Male
# 3   1     3       0       Absence    Male
# 4   3     2       0       Absence  female

# %%
#Converting numerical data into Categorical Data
def age_rng(p):
    if p>=29 and p<40:
        return 'Young Age'
    elif p>=40 and p<55:
        return 'Middle Age'
    elif p>55:
        return 'Elder Age'

# %%
df['Age_Range']=df['age'].apply(age_rng)
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target Heart_Disease    sex1   Age_Range
# 0   2     3       0       Absence    Male  Middle Age
# 1   0     3       0       Absence    Male  Middle Age
# 2   0     3       0       Absence    Male   Elder Age
# 3   1     3       0       Absence    Male   Elder Age
# 4   3     2       0       Absence  female   Elder Age

# %%
# !pip install pandas-profiling
# Out:
# Requirement already satisfied: pandas-profiling in c:\users\91960\anaconda3\lib\site-packages (3.2.0)
# Requirement already satisfied: joblib~=1.1.0 in c:\users\91960\anaconda3\lib\site-packages (from pandas-profiling) (1.1.1)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\91960\anaconda3\lib\site-packages (from pandas-profiling) (1.13.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\91960\anaconda3\lib\site-packages (from pandas-profiling) (2.2.2)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\91960\anaconda3\lib\site-packages (from pandas-profiling) (3.8.4)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\91960\anaconda3\lib\site-packages (from pandas-profiling) (2.5.3)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\91960\anaconda3\lib\site-packages (from pandas-profiling) (6.0.1)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\91960\anaconda3\lib\site-packages (from pandas-profiling) (3.1.4)
# Requirement already satisfied: markupsafe~=2.1.1 in c:\users\91960\anaconda3\lib\site-packages (from pandas-profiling) (2.1.3)
# Requirement already satisfied: visions==0.7.4 in c:\users\91960\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (0.7.4)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\91960\anaconda3\lib\site-packages (from pandas-profiling) (1.26.4)
# Requirement already satisfied: htmlmin>=0.1.12 in c:\users\91960\anaconda3\lib\site-packages (from pandas-profiling) (0.1.12)
# Requirement already satisfied: missingno>=0.4.2 in c:\users\91960\anaconda3\lib\site-packages (from pandas-profiling) (0.5.2)
# Requirement already satisfied: phik>=0.11.1 in c:\users\91960\anaconda3\lib\site-packages (from pandas-profiling) (0.12.4)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in c:\users\91960\anaconda3\lib\site-packages (from pandas-profiling) (0.2.0)
# Requirement already satisfied: requests>=2.24.0 in c:\users\91960\anaconda3\lib\site-packages (from pandas-profiling) (2.32.2)
# Requirement already satisfied: tqdm>=4.48.2 in c:\users\91960\anaconda3\lib\site-packages (from pandas-profiling) (4.66.4)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\91960\anaconda3\lib\site-packages (from pandas-profiling) (0.13.2)
# Requirement already satisfied: multimethod>=1.4 in c:\users\91960\anaconda3\lib\site-packages (from pandas-profiling) (1.12)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\91960\anaconda3\lib\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\91960\anaconda3\lib\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling) (3.2.1)
# Requirement already satisfied: imagehash in c:\users\91960\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (4.3.1)
# Requirement already satisfied: Pillow in c:\users\91960\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (10.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\91960\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\91960\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\91960\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\91960\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\91960\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\91960\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\91960\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\91960\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\91960\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\91960\anaconda3\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\91960\anaconda3\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (2.14.6)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\91960\anaconda3\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\91960\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\91960\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\91960\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\91960\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2024.7.4)
# Requirement already satisfied: colorama in c:\users\91960\anaconda3\lib\site-packages (from tqdm>=4.48.2->pandas-profiling) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\91960\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling) (1.16.0)
# Requirement already satisfied: PyWavelets in c:\users\91960\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling) (1.5.0)

# %%
from pandas_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 from pandas_profiling import ProfileReport
#
# File ~\anaconda3\Lib\site-packages\pandas_profiling\__init__.py:6
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# File ~\anaconda3\Lib\site-packages\pandas_profiling\controller\pandas_decorator.py:4
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       7 def profile_report(df: DataFrame, **kwargs) -> ProfileReport:
#       8     """Profile a DataFrame.
#       9
#      10     Args:
#    (...)
#      15         A ProfileReport of the DataFrame.
#      16     """
#
# File ~\anaconda3\Lib\site-packages\pandas_profiling\profile_report.py:11
#       9 import yaml
#      10 from tqdm.auto import tqdm
# ---> 11 from visions import VisionsTypeset
#      13 from pandas_profiling.config import Config, Settings
#      14 from pandas_profiling.expectations_report import ExpectationsReport
#
# File ~\anaconda3\Lib\site-packages\visions\__init__.py:4
#       1 """Core functionality"""
#       3 from visions import types, typesets, utils
# ----> 4 from visions.backends import *
#       5 from visions.declarative import create_type
#       6 from visions.functional import (
#       7     cast_to_detected,
#       8     cast_to_inferred,
#       9     detect_type,
#      10     infer_type,
#      11 )
#
# File ~\anaconda3\Lib\site-packages\visions\backends\__init__.py:9
#       6 try:
#       7     import pandas as pd
# ----> 9     import visions.backends.pandas
#      10     from visions.backends.pandas.test_utils import pandas_version
#      12     if pandas_version[0] < 1:
#
# File ~\anaconda3\Lib\site-packages\visions\backends\pandas\__init__.py:2
#       1 import visions.backends.pandas.traversal
# ----> 2 import visions.backends.pandas.types
#
# File ~\anaconda3\Lib\site-packages\visions\backends\pandas\types\__init__.py:3
#       1 import visions.backends.pandas.types.boolean
#       2 import visions.backends.pandas.types.categorical
# ----> 3 import visions.backends.pandas.types.complex
#       4 import visions.backends.pandas.types.count
#       5 import visions.backends.pandas.types.date
#
# File ~\anaconda3\Lib\site-packages\visions\backends\pandas\types\complex.py:7
#       5 from visions.backends.pandas.series_utils import series_not_empty, series_not_sparse
#       6 from visions.backends.pandas.types.float import string_is_float
# ----> 7 from visions.backends.shared.parallelization_engines import pandas_apply
#       8 from visions.types.complex import Complex
#       9 from visions.types.string import String
#
# File ~\anaconda3\Lib\site-packages\visions\backends\shared\__init__.py:1
# ----> 1 from . import nan_handling, parallelization_engines, utilities
#
# File ~\anaconda3\Lib\site-packages\visions\backends\shared\nan_handling.py:34
#      30 # TODO: There are optimizations here, just have to define precisely the desired missing ruleset in the
#      31 # generated jit
#      32 if has_numba:
# ---> 34     @nb.generated_jit(nopython=True)
#      35     def is_missing(x):
#      36         """
#      37         Return True if the value is missing, False otherwise.
#      38         """
#      39         if isinstance(x, nb.types.Float):
#
# AttributeError: module 'numba' has no attribute 'generated_jit'

# %% [markdown]
# # Data Transformation

# %%
# We calculate the mean and median of ca and thal coulmn to be replaced in place of -100000.
#From below calculation, we come to know that median and mode for both 'ca' and 'thal' are 0.0 and 3.0
#So we will replace the -100000 with 0.0 in 'ca' and 3.0 in 'thal'

# %%
#Replacing 0 in 'ca' where value = -100000

ca_median = int(df['ca'].median())
df.loc[df.ca == -100000, 'ca'] = np.nan
df.fillna(ca_median,inplace =True)

# %%
df['ca']
# Out:
# 0       2.0
# 1       0.0
# 2       0.0
# 3       1.0
# 4       3.0
#        ...
# 1020    0.0
# 1021    1.0
# 1022    1.0
# 1023    0.0
# 1024    1.0
# Name: ca, Length: 1025, dtype: float64

# %%
#replacing 3 in 'thal' where value = -100000
thal_median = int(df['thal'].median())
df.loc[df.ca == -100000, 'thal'] = np.nan
df.fillna(thal_median,inplace =True)

# %%
df['thal']
# Out:
# 0       3.0
# 1       3.0
# 2       3.0
# 3       3.0
# 4       2.0
#        ...
# 1020    2.0
# 1021    3.0
# 1022    2.0
# 1023    2.0
# 1024    3.0
# Name: thal, Length: 1025, dtype: float64

# %%
df.dtypes
# Out:
# age                int64
# sex                int64
# cp                 int64
# trestbps           int64
# chol               int64
# fbs                int64
# restecg            int64
# thalach            int64
# exang              int64
# oldpeak          float64
# slope              int64
# ca               float64
# thal             float64
# target             int64
# Heart_Disease     object
# sex1              object
# Age_Range         object
# dtype: object

# %%
#converting the numeric columns to categorical
df = df.astype({"sex" : 'category',"cp" : 'category',"fbs" :'category',"restecg":'category',"exang":'category',"slope":'category',"ca":'category',"thal":'category',"target":'category'})

# %%
df.dtypes
# Out:
# age                 int64
# sex              category
# cp               category
# trestbps            int64
# chol                int64
# fbs              category
# restecg          category
# thalach             int64
# exang            category
# oldpeak           float64
# slope            category
# ca               category
# thal             category
# target           category
# Heart_Disease      object
# sex1               object
# Age_Range          object
# dtype: object

# %%
df
# Out:
#       age sex cp  trestbps  chol fbs restecg  thalach exang  oldpeak slope  \
# 0      52   1  0       125   212   0       1      168     0      1.0     2
# 1      53   1  0       140   203   1       0      155     1      3.1     0
# 2      70   1  0       145   174   0       1      125     1      2.6     0
# 3      61   1  0       148   203   0       1      161     0      0.0     2
# 4      62   0  0       138   294   1       1      106     0      1.9     1
# ...   ...  .. ..       ...   ...  ..     ...      ...   ...      ...   ...
# 1020   59   1  1       140   221   0       1      164     1      0.0     2
# 1021   60   1  0       125   258   0       0      141     1      2.8     1
# 1022   47   1  0       110   275   0       0      118     1      1.0     1
# 1023   50   0  0       110   254   0       0      159     0      0.0     2
# 1024   54   1  0       120   188   0       1      113     0      1.4     1
#
#        ca thal target Heart_Disease    sex1   Age_Range
# 0     2.0  3.0      0       Absence    Male  Middle Age
# 1     0.0  3.0      0       Absence    Male  Middle Age
# 2     0.0  3.0      0       Absence    Male   Elder Age
# 3     1.0  3.0      0       Absence    Male   Elder Age
# 4     3.0  2.0      0       Absence  female   Elder Age
# ...   ...  ...    ...           ...     ...         ...
# 1020  0.0  2.0      1      Presence    Male   Elder Age
# 1021  1.0  3.0      0       Absence    Male   Elder Age
# 1022  1.0  2.0      0       Absence    Male  Middle Age
# 1023  0.0  2.0      1      Presence  female  Middle Age
# 1024  1.0  3.0      0       Absence    Male  Middle Age
#
# [1025 rows x 17 columns]

# %%
df.dtypes[df.dtypes=='category']
# Out:
# sex        category
# cp         category
# fbs        category
# restecg    category
# exang      category
# slope      category
# ca         category
# thal       category
# target     category
# dtype: object

# %%
df.describe()
# Out:
#                age     trestbps        chol      thalach      oldpeak
# count  1025.000000  1025.000000  1025.00000  1025.000000  1025.000000
# mean     54.434146   131.611707   246.00000   149.114146     1.071512
# std       9.072290    17.516718    51.59251    23.005724     1.175053
# min      29.000000    94.000000   126.00000    71.000000     0.000000
# 25%      48.000000   120.000000   211.00000   132.000000     0.000000
# 50%      56.000000   130.000000   240.00000   152.000000     0.800000
# 75%      61.000000   140.000000   275.00000   166.000000     1.800000
# max      77.000000   200.000000   564.00000   202.000000     6.200000

# %%
#Boxplot before outlier treatment for proper visualisation of the outliers and how far they from mean

# %%
plt.subplots(figsize=(20,15))
plt.boxplot(data= df, x = 'chol')
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25f55537e90>,
#   <matplotlib.lines.Line2D at 0x25f55537a40>],
#  'caps': [<matplotlib.lines.Line2D at 0x25f5556c1a0>,
#   <matplotlib.lines.Line2D at 0x25f5556c980>],
#  'boxes': [<matplotlib.lines.Line2D at 0x25f5343c290>],
#  'medians': [<matplotlib.lines.Line2D at 0x25f5556cb00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x25f5556c7d0>],
#  'means': []}

# %%
df['chol'].mean()
# Out:
# 246.0

# %%
outliers_chol = []
def Find_Outliers(data):
    data = sorted(data)
    Q1 = np.percentile(data,25)
    Q3 = np.percentile(data,75)

    IQR = Q3-Q1
    l_bound = Q1-(1.5*IQR)
    u_bound = Q3+(1.5*IQR)

    for j in data:
         if (j < l_bound or j > u_bound):
             outliers_chol.append(j)
    return outliers_chol

outliers_chol =Find_Outliers(df['chol'])
print("Outliers method from IQR method chol column: ", outliers_chol)
# Out:
# Outliers method from IQR method chol column:  [394, 394, 394, 407, 407, 407, 407, 409, 409, 409, 417, 417, 417, 564, 564, 564]
